# %%
import os
import openai

openai.api_key = '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'

#dataset_kind = input()


response = openai.Completion.create(
  engine="davinci-codex",
  prompt="\"\"\"\npython3\n\nGiven a european car dataset in the file \"datasets/cars.csv\" with the following columns:\nprice,brand,model,year,title_status,mileage,color,vin,lot,state,country,condition\n Plot the Histograms for the year and brand Columns \n\"\"\"\n",
  temperature=0.15,
  max_tokens=400,
  top_p=1,
  frequency_penalty=0.2,
  presence_penalty=0
)
print(response)
# Out:
# {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "text": "\nimport pandas as pd\nimport matplotlib.pyplot as plt\n\ndf = pd.read_csv('datasets/cars.csv')\n\n# Plotting the histogram for year column\nplt.hist(df['year'], bins=10)\nplt.title('Histogram for Year')\nplt.xlabel('Year')\nplt.ylabel('Count')\nplt.show()\n\n# Plotting the histogram for brand column\nplt.hist(df['brand'], bins=10)\nplt.title('Histogram for Brand')\nplt.xlabel('Brand')\nplt.ylabel('Count')\nplt.show()"
#     }
#   ],
#   "created": 1641798900,
#   "id": "cmpl-4OjBM2R6GswzesbMQTuZp0UK1QRps",
#   "model": "davinci-codex:2021-08-03",
#   "object": "text_completion"
# }

# %%
os.remove('code_g.py')
with open('code_g.py', 'x') as f:
    f.write(response['choices'][0]['text'])

# %%
ss

# %%
import os
import openai

openai.api_key = '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'

#dataset_kind = input()


response = openai.Completion.create(
  engine="davinci-codex",
  prompt="\"\"\"\npython3\n\nGiven a european car dataset in the file \"datasets/cars.csv\" with the following columns:\nprice,brand,model,year,title_status,mileage,color,vin,lot,state,country,condition\n Plot the Heatmap for all the columns \n find the column having second highest correlation with price  \n\"\"\"\n",
  temperature=0.15,
  max_tokens=700,
  top_p=1,
  frequency_penalty=0.2,
  presence_penalty=0
)
print(response)
# Out:
# {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "text": "\nimport pandas as pd\nimport matplotlib.pyplot as plt\nimport seaborn as sns\n\n# read the dataset\ndata = pd.read_csv(\"datasets/cars.csv\")\n\n# print the columns of the dataset\nprint(data.columns)\n\n# plot the heatmap for all the columns in the dataset\nplt.figure(figsize=(20,10))\nsns.heatmap(data.corr(),annot=True)\nplt.show()\n\n\n# find the column having second highest correlation with price  \nprint(data.corr()['price'].sort_values(ascending=False)[1])"
#     }
#   ],
#   "created": 1641800099,
#   "id": "cmpl-4OjUh6Iqn8HSlz4hMrOBCSNsHMgt1",
#   "model": "davinci-codex:2021-08-03",
#   "object": "text_completion"
# }

# %%
os.remove('code_g1.py')
with open('code_g1.py', 'x') as f:
    f.write(response['choices'][0]['text'])

# %%
exec(open('code_g1.py').read())
# Out:
# Index(['Unnamed: 0', 'price', 'brand', 'model', 'year', 'title_status',
#        'mileage', 'color', 'vin', 'lot', 'state', 'country', 'condition'],
#       dtype='object')
# 0.41827356849176
